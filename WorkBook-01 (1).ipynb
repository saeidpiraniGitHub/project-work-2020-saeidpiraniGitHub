# %%
import numpy as np
import sympy as sy
from ipywidgets import interactive
from sympy import init_session
import matplotlib.pyplot as plt

##################################################################
##    Important Notice
##    In CST txt file first remember to change ',' to '.' for number floating point 
##         then delete all ';' charachters in the txt file
####################################################

### In this code 1st we save electron collision energy for each of field emission sites separately
###    After collecting all emission electrons energy in separate files in the 2nd part we combine 
###    all of mentioned files and our code will count how many electrons with identical collisions 
###    energies exist and plot them. So final out put will be similar to scintillator out put.

######### After implementation of above mentioned changes open txt file 

f = open('16.7MV 200deg-iris4-right.txt', 'r')
array01 = np.array(f.read().splitlines())
f.close()
print('\n',array01,'\n')

L1=len(array01)

x01=list()
i=0
while i<L1:
    x00=array01[i][0:15]
    x01.append(x00)
    i=i+1

############## looking at txt file we will find out that initial and collision energy of electron
#####               is extractable around '# Energy '.
x02=list()
x03=list()
i=0
i2=1

while i<L1-1:
    if x01[i]=='# Energy ':
        x02.append(i2)
        x02.append(x01[i-4])
        x02.append(x01[i])
        x02.append(x01[i+1])
        i2=i2+1
    i=i+1

L2=len(x02)
print('L2 is:  ', L2)


#### Now we do some arrangement to have electron number first, then electron initial energy and then 
####        electron collision energy. This will be repeated for all electrons.

i1=0
i2=0
while i1<L2-1:
    if x02[i1]=='# Energy ':
        x03.append(i2)
        a1=float(x02[i1+1])
        a2=float(x02[i1-1])
        x03.append(a1)
        x03.append(a2)
        i2=i2+1
            
    i1=i1+1

L3=len(x03)
print('L3 is:  ',L3)

### For checking x03 we can use on of following commands:

##x03

#for st in x03:
#    print(st)

############################################
##   As we only need electron collision energy so put them in x04 and then use sort() function

x04=list()
i1=0
i2=0
while i1<L3-1:
    x04.append(x03[2+i1])
    i1=i1+3

x04 = [int(x) for x in x04]
x04.sort()

print('electron max collision energy is:', max(x04))
L4=len(x04)
print('x04 length is:', len(x04))  

##### We can check x04
#for st in x04:
#    print(st)
    
##### Considering electron emission site select a proper name for saving collision energies 
###             File containing collision energies will be used later
with open('16.7MV-iris4-right 200-.txt', 'w') as f:    
   for st in x04:
        print(st, file=f)

        
##### for graphical check we and in order to have better visualy graph we turn 1st 4 digits of 
###           collision energy to zero to increase number of collision energies with identical 
###           value. 

x05=list()
for tt1 in x04:
    tt1=10000*int(tt1/10000)
    x05.append(tt1)
    
#### Count identical energies    
p01=list()
p02=list()
i1=0
i2=0
while i1<L4-1:
    z01=x05.count(x05[i1])
    p01.append(z01)
    p02.append(x05[i1])
    i1=i1+1
# Out:
#  ['# Trajectories' '# Trajectory 0' '# Energy ' ... ' 585939.7 '
#  ' 587010.5 ' '']
#
# L2 is:   6080
# L3 is:   4560
# electron max collision energy is: 6395035
# x04 length is: 1520

# %%
from pylab import rcParams
from matplotlib.pyplot import *
rcParams['figure.figsize'] = 10, 4
matplotlib.rcParams.update({'font.size': 15})

plt.plot(p02, p01, '.');
plt.xlim((0,8500000))
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.xlabel('Energy [eV]')
plt.ylabel('counts')
plt.grid()

plt.figure()
plt.plot(x05, '.');
plt.ylabel('Energy [eV]')
plt.grid()

# %%
filenames = ['16.7MV-iris1-right -90-.txt','16.7MV-iris1-right -80-.txt','16.7MV-iris1-right -70-.txt','16.7MV-iris1-right -60-.txt','16.7MV-iris1-right -50-.txt','16.7MV-iris1-right -40-.txt','16.7MV-iris1-right -30-.txt','16.7MV-iris1-right -20-.txt','16.7MV-iris1-right -10-.txt','16.7MV-iris1-right 0-.txt','16.7MV-iris1-right 10-.txt','16.7MV-iris1-right 20-.txt','16.7MV-iris1-right 30-.txt','16.7MV-iris1-right 40-.txt','16.7MV-iris1-right 50-.txt','16.7MV-iris1-right 60-.txt','16.7MV-iris2-left 90-.txt','16.7MV-iris2-left 100-.txt','16.7MV-iris2-left 110-.txt','16.7MV-iris2-left 120-.txt','16.7MV-iris2-left 130-.txt','16.7MV-iris2-left 140-.txt','16.7MV-iris2-left 150-.txt','16.7MV-iris2-left 160-.txt','16.7MV-iris2-left 170-.txt','16.7MV-iris2-left 180-.txt','16.7MV-iris2-left 190-.txt','16.7MV-iris2-left 200-.txt','16.7MV-iris2-left 210-.txt','16.7MV-iris2-left 220-.txt','16.7MV-iris2-left 230-.txt','16.7MV-iris2-left 240-.txt','16.7MV-iris2-left 250-.txt','16.7MV-iris2-right 90-.txt','16.7MV-iris2-right 100-.txt','16.7MV-iris2-right 110-.txt','16.7MV-iris2-right 120-.txt','16.7MV-iris2-right 130-.txt','16.7MV-iris2-right 140-.txt','16.7MV-iris2-right 150-.txt','16.7MV-iris2-right 160-.txt','16.7MV-iris2-right 170-.txt','16.7MV-iris2-right 180-.txt','16.7MV-iris2-right 190-.txt','16.7MV-iris2-right 200-.txt','16.7MV-iris2-right 210-.txt','16.7MV-iris2-right 220-.txt','16.7MV-iris2-right 230-.txt','16.7MV-iris2-right 240-.txt','16.7MV-iris2-right 250-.txt','16.7MV-iris3-left -90-.txt','16.7MV-iris3-left -80-.txt','16.7MV-iris3-left -70-.txt','16.7MV-iris3-left -60-.txt','16.7MV-iris3-left -50-.txt','16.7MV-iris3-left -40-.txt','16.7MV-iris3-left -30-.txt','16.7MV-iris3-left -20-.txt','16.7MV-iris3-left -10-.txt','16.7MV-iris3-left 0-.txt','16.7MV-iris3-left 10-.txt','16.7MV-iris3-left 20-.txt','16.7MV-iris3-left 30-.txt','16.7MV-iris3-left 40-.txt','16.7MV-iris3-left 50-.txt','16.7MV-iris3-left 60-.txt','16.7MV-iris3-right -90-.txt','16.7MV-iris3-right -80-.txt','16.7MV-iris3-right -70-.txt','16.7MV-iris3-right -60-.txt','16.7MV-iris3-right -50-.txt','16.7MV-iris3-right -40-.txt','16.7MV-iris3-right -30-.txt','16.7MV-iris3-right -20-.txt','16.7MV-iris3-right -10-.txt','16.7MV-iris3-right 0-.txt','16.7MV-iris3-right 10-.txt','16.7MV-iris3-right 20-.txt','16.7MV-iris3-right 30-.txt','16.7MV-iris3-right 40-.txt','16.7MV-iris3-right 50-.txt','16.7MV-iris3-right 60-.txt','16.7MV-iris4-left 90-.txt','16.7MV-iris4-left 100-.txt','16.7MV-iris4-left 110-.txt','16.7MV-iris4-left 120-.txt','16.7MV-iris4-left 130-.txt','16.7MV-iris4-left 140-.txt','16.7MV-iris4-left 150-.txt','16.7MV-iris4-left 160-.txt','16.7MV-iris4-left 170-.txt','16.7MV-iris4-left 180-.txt','16.7MV-iris4-left 190-.txt','16.7MV-iris4-left 200-.txt','16.7MV-iris4-left 210-.txt','16.7MV-iris4-left 220-.txt','16.7MV-iris4-left 230-.txt','16.7MV-iris4-left 240-.txt','16.7MV-iris4-left 250-.txt','16.7MV-iris4-right 90-.txt','16.7MV-iris4-right 100-.txt','16.7MV-iris4-right 110-.txt','16.7MV-iris4-right 120-.txt','16.7MV-iris4-right 130-.txt','16.7MV-iris4-right 140-.txt','16.7MV-iris4-right 150-.txt','16.7MV-iris4-right 160-.txt','16.7MV-iris4-right 170-.txt','16.7MV-iris4-right 180-.txt','16.7MV-iris4-right 190-.txt','16.7MV-iris4-right 200-.txt','16.7MV-iris4-right 210-.txt','16.7MV-iris4-right 220-.txt','16.7MV-iris4-right 230-.txt','16.7MV-iris4-right 240-.txt']
with open('phase0to-60.txt', 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            for line in infile:
                outfile.write(line)
                
                
f = open('phase0to-60.txt', 'r')
fieldemission00 = np.array(f.read().splitlines())
f.close()

LL=len(fieldemission00)
print(LL)

fieldemission01 = [int(x) for x in fieldemission00]
fieldemission01.sort()


fieldemission02=list()
for tt1 in fieldemission01:
    tt1=10000*int(tt1/10000)
    fieldemission02.append(tt1)

    
xx01=list()
yy01=list()

i1=0
i2=0
while i1<LL-1:
    zz=fieldemission02.count(fieldemission02[i1])
    print(fieldemission02[i1], zz)
    yy01.append(zz)
    xx01.append(fieldemission02[i1])
    i1=i1+1
# Out:
# 176882
# 0 11
# 0 11
# 0 11
# 0 11
# 0 11
# 0 11
# 0 11
# 0 11
# 0 11
# 0 11
# 0 11
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 10000 61
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# 20000 121
# ...

# %%
rcParams['figure.figsize'] = 10, 6

plt.plot(xx01, yy01, '.');
plt.xlabel('Energy [eV]')
plt.ylabel('counts')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

plt.grid()     

with open('xx01.txt', 'w') as f:    
    for st in xx01:
        print(st, file=f)
        
with open('yy01.txt', 'w') as f:    
    for st in yy01:
        print(st, file=f)
